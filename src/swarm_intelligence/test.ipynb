# %% [markdown]
# # Stage 1

# %% [markdown]
# In this step, my goal is to implement a task distribution system with information gathering. Assume I have 5 agents, all of whome have a random chance of finding a task. Once a task is found, the agent will broadcast the task to all other agents. The agents will then decide which agent is best suited to complete the task. The agent that is best suited to complete the task will then be assigned the task.

# %%
from typing import Any
import random

def get_info():
    """Simulating information gathering"""

    tasks = list("abcde")
    number_of_tasks = random.randint(1, len(tasks))
    return random.sample(tasks, number_of_tasks)

# %%
for i in range(10):
    print(get_info())
# Out:
# ['b', 'd', 'c', 'a', 'e']
# ['e', 'd', 'a']
# ['c']
# ['e']
# ['e']
# ['a', 'e', 'b', 'd']
# ['b']
# ['c', 'e', 'a']
# ['b']
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### Iteration 1: Information Gathering

# %%
class Agent:
    """A basic agent class that can gather information, store it, and be assigned tasks"""
    def __init__(self, id: int):
        self.id = id
        self.captured_info = None
        self.gathered_info = None
        self.assigned_task = None
        
    def get_info(self) -> Any:
        if self.captured_info is None:
            self.captured_info = get_info()
        return self.captured_info
    
    def __str__(self):
        return str(
            {
                "id": self.id,
                "captured_info": self.captured_info,
                "gathered_info": self.gathered_info,
                "assigned_task": self.assigned_task
            }
        )

# %%
A = Agent(1)
A.get_info()
print(A)
# Out:
# {'id': 1, 'captured_info': ['e', 'a'], 'gathered_info': None, 'assigned_task': None}

# %% [markdown]
# ### Iteration 2: Information Sharing

# %%
import threading
class Agent:
    """A basic agent class that can gather information, store it, and be assigned tasks
    Now with thread safety!
    Given a list of all other agents, if can share its captured tasks with them.
    """
    
    def __init__(self, id: int):
        self.id = id
        self.captured_info = None
        self.gathered_info = set()  # Set to track known tasks from all agents
        self.assigned_task = None
        self.lock = threading.Lock()

    def get_info(self) -> Any:
        if self.captured_info is None:
            self.captured_info = get_info()
        return self.captured_info
    
    def share_info(self, agent_list):
        """Share captured tasks with other agents."""
        for agent in agent_list:
            if agent.id != self.id:
                with agent.lock:  # Ensure thread-safe updates
                    agent.gathered_info.update(self.captured_info)

    def __str__(self):
        return str(
            {
                "id": self.id,
                "captured_info": self.captured_info,
                "gathered_info": self.gathered_info,
                "assigned_task": self.assigned_task
            }
        )

# %%
# Initialization
agent_1 = Agent(1)
agent_2 = Agent(2)

# Information Gathering
agent_1.get_info()
agent_2.get_info()

# Sharing information
agent_1.share_info([agent_2])
agent_2.share_info([agent_1])

# Displaying the agents
print(agent_1)
print(agent_2)
# Out:
# {'id': 1, 'captured_info': ['b'], 'gathered_info': {'a'}, 'assigned_task': None}
# {'id': 2, 'captured_info': ['a'], 'gathered_info': {'b'}, 'assigned_task': None}

# %% [markdown]
# ### Iteration 3: multithreaded task assignment

# %%
import threading
import time
import random
from queue import Queue

class Agent(threading.Thread):
    def __init__(self, id: int, result_lock: threading.Lock):
        super().__init__()
        self.id = id
        self.captured_info = set()
        self.assigned_task = None
        self.task_queue = Queue()
        self.result_lock = result_lock
        self.neighbors = []
        
    def get_info(self):
        """Capture initial tasks."""
        tasks = list("abcde")
        number_of_tasks = random.randint(1, len(tasks))
        self.captured_info.update(random.sample(tasks, number_of_tasks))

    def broadcast_info(self):
        """Broadcast task information to neighbors."""
        for neighbor in self.neighbors:
            neighbor.task_queue.put((self.id, self.captured_info))

    def listen_for_info(self):
        """Listen for task updates from neighbors."""
        while not self.task_queue.empty():
            sender_id, tasks = self.task_queue.get()
            print(f"Agent {self.id} received tasks {tasks} from Agent {sender_id}")
            self.captured_info.update(tasks)

    def assign_unique_task(self, assigned_tasks):
        """Choose a unique task."""
        available_tasks = self.captured_info - assigned_tasks
        if available_tasks:
            self.assigned_task = available_tasks.pop()
            assigned_tasks.add(self.assigned_task)

    def run(self):
        """Main agent behavior."""
        # Step 1: Capture tasks
        self.get_info()

        # Step 2: Broadcast initial tasks
        self.broadcast_info()

        # Step 3: Listen and update from neighbors
        time.sleep(0.5)  # Allow time for messages to propagate
        self.listen_for_info()

        # Synchronize task assignment
        with self.result_lock:
            self.assign_unique_task(assigned_tasks)

        print(f"Agent {self.id} assigned task: {self.assigned_task}")

# %%
# Shared resources
NUM_AGENTS = 5
assigned_tasks = set()
result_lock = threading.Lock()

# Create agents
agents = [Agent(id=i, result_lock=result_lock) for i in range(NUM_AGENTS)]

# Link agents as neighbors (fully connected graph)
for i, agent in enumerate(agents):
    agent.neighbors = [a for j, a in enumerate(agents) if i != j]

# Start all agents
for agent in agents:
    agent.start()

# Wait for all agents to complete
for agent in agents:
    agent.join()

# Show the final state
print("\nFinal Agent States:")
for agent in agents:
    print(f"Agent {agent.id}: Assigned Task = {agent.assigned_task}")
# Out:
# Agent 0 received tasks {'a'} from Agent 1Agent 4 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 0
# Agent 4 received tasks {'a'} from Agent 1
# Agent 4 received tasks {'d', 'c'} from Agent 2
# Agent 4 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 3
# Agent 4 assigned task: e
# Agent 3 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 0
# Agent 3 received tasks {'a'} from Agent 1
# Agent 3 received tasks {'d', 'c'} from Agent 2
# Agent 3 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 4
# Agent 3 assigned task: d
# Agent 2 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 0
# Agent 2 received tasks {'a'} from Agent 1
# Agent 2 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 3
# Agent 2 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 4
# Agent 2 assigned task: c
# Agent 1 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 0
# Agent 1 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 2
# Agent 1 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 3
# Agent 1 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 4
# Agent 1 assigned task: a
#
# Agent 0 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 2
# Agent 0 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 3
# Agent 0 received tasks {'d', 'c', 'b', 'e', 'a'} from Agent 4
# Agent 0 assigned task: b
#
# Final Agent States:
# Agent 0: Assigned Task = b
# Agent 1: Assigned Task = a
# Agent 2: Assigned Task = c
# Agent 3: Assigned Task = d
# Agent 4: Assigned Task = e

# %% [markdown]
# ### Iteration 4: Over the network task assignment

# %%
import socket
import threading
import json
import random
import time

HOST = "127.0.0.1"
BASE_PORT = 5000
NUM_AGENTS = 5

class Agent(threading.Thread):
    def __init__(self, id: int):
        super().__init__()
        self.id = id
        self.tasks = set()
        self.assigned_task = None
        self.port = BASE_PORT + id
        self.neighbor_ports = [BASE_PORT + i for i in range(NUM_AGENTS) if i != id]
        self.server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.server_socket.bind((HOST, self.port))
        self.server_socket.listen()
        self.running = True  # Flag to control the listening loop

    def get_info(self):
        """Capture initial tasks."""
        tasks = list("abc")
        number_of_tasks = random.randint(1, len(tasks))
        self.tasks.update(random.sample(tasks, number_of_tasks))
        print(f"Agent {self.id} initial tasks: {self.tasks}")

    def listen_for_messages(self):
        """Listen for incoming task information."""
        while self.running:
            try:
                conn, _ = self.server_socket.accept()
                with conn:
                    data = conn.recv(1024)
                    if data:
                        message = json.loads(data.decode())
                        print(f"Agent {self.id} received: {message}")
                        self.tasks.update(message["tasks"])
            except socket.timeout:
                continue  # Allow graceful shutdown during blocking accept
            except Exception as e:
                if self.running:
                    print(f"Agent {self.id} error: {e}")
                break

    def send_task_info(self):
        """Send task information to neighbors."""
        message = json.dumps({"id": self.id, "tasks": list(self.tasks)})
        for port in self.neighbor_ports:
            try:
                with socket.create_connection((HOST, port), timeout=1) as sock:
                    sock.sendall(message.encode())
            except (ConnectionRefusedError, socket.timeout):
                print(f"Agent {self.id} failed to connect to Agent at port {port}")

    def assign_unique_task(self, assigned_tasks):
        """Choose a unique task."""
        available_tasks = self.tasks - assigned_tasks
        if available_tasks:
            self.assigned_task = available_tasks.pop()
            assigned_tasks.add(self.assigned_task)
        print(f"Agent {self.id} assigned task: {self.assigned_task}")

    def run(self):
        """Main agent behavior."""
        self.get_info()

        # Start listener thread for incoming messages
        listener_thread = threading.Thread(target=self.listen_for_messages, daemon=True)
        listener_thread.start()

        # Broadcast task information
        time.sleep(1)  # Allow time for all agents to start
        self.send_task_info()

        # Wait for task propagation
        time.sleep(2)

        # Task assignment phase
        with result_lock:
            self.assign_unique_task(assigned_tasks)

        # Close the socket and stop listening
        self.stop_listening()

    def stop_listening(self):
        """Close the server socket and stop the listening loop."""
        self.running = False
        self.server_socket.close()
        print(f"Agent {self.id}: Server socket closed.")

# %%
# Shared resources
assigned_tasks = set()
result_lock = threading.Lock()

# Create and start agents
agents = [Agent(id=i) for i in range(NUM_AGENTS)]
for agent in agents:
    agent.start()

# Wait for all agents to complete
for agent in agents:
    agent.join()

print("\nFinal Agent States:")
for agent in agents:
    print(f"Agent {agent.id}: Assigned Task = {agent.assigned_task}")
# Out:
# Agent 0 initial tasks: {'a', 'c', 'b'}
# Agent 1 initial tasks: {'a', 'c'}
# Agent 2 initial tasks: {'a', 'c', 'b'}
# Agent 3 initial tasks: {'c'}
# Agent 4 initial tasks: {'a', 'c', 'b'}
# Agent 0 received: {'id': 1, 'tasks': ['a', 'c']}Agent 1 received: {'id': 0, 'tasks': ['a', 'c', 'b']}
#
# Agent 0 received: {'id': 3, 'tasks': ['c']}
# Agent 0 received: {'id': 2, 'tasks': ['a', 'c', 'b']}
# Agent 2 received: {'id': 1, 'tasks': ['a', 'c']}
# Agent 2 received: {'id': 0, 'tasks': ['a', 'c', 'b']}
# Agent 1 received: {'id': 3, 'tasks': ['c']}
# Agent 0 received: {'id': 4, 'tasks': ['a', 'c', 'b']}
# Agent 1 received: {'id': 2, 'tasks': ['a', 'c', 'b']}
# Agent 1 received: {'id': 4, 'tasks': ['a', 'c', 'b']}
# Agent 3 received: {'id': 1, 'tasks': ['a', 'c']}
# Agent 2 received: {'id': 3, 'tasks': ['c']}
# Agent 3 received: {'id': 0, 'tasks': ['a', 'c', 'b']}
# Agent 3 received: {'id': 2, 'tasks': ['a', 'c', 'b']}
# Agent 2 received: {'id': 4, 'tasks': ['a', 'c', 'b']}
# Agent 4 received: {'id': 1, 'tasks': ['a', 'c']}
# Agent 4 received: {'id': 2, 'tasks': ['a', 'c', 'b']}
# Agent 3 received: {'id': 4, 'tasks': ['a', 'c', 'b']}
# Agent 4 received: {'id': 3, 'tasks': ['c']}
# Agent 4 received: {'id': 0, 'tasks': ['a', 'c', 'b']}
# Agent 0 assigned task: a
# Agent 4 assigned task: c
# Agent 0: Server socket closed.
# Agent 4: Server socket closed.
# Agent 1 assigned task: b
# Agent 3 assigned task: None
# Agent 2 assigned task: None
# Agent 1: Server socket closed.
# Agent 3: Server socket closed.
# Agent 2: Server socket closed.
#
# Final Agent States:
# Agent 0: Assigned Task = a
# Agent 1: Assigned Task = b
# Agent 2: Assigned Task = None
# Agent 3: Assigned Task = None
# Agent 4: Assigned Task = c

# %% [markdown]
# ### Stage 4: Network Discovery

# %%
import socket
import threading
import json
import random
import time

HOST = "127.0.0.1"
BASE_PORT = 5000
PORT_RANGE = 10  # Adjust for the number of agents

class Agent(threading.Thread):
    def __init__(self, id: int):
        super().__init__()
        self.id = id
        self.tasks = set()
        self.assigned_task = None
        self.port = BASE_PORT + id
        self.neighbor_ports = []
        self.server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.server_socket.bind((HOST, self.port))
        self.server_socket.listen()
        self.server_socket.settimeout(1)
        self.running = True

    def get_info(self):
        """Capture initial tasks."""
        tasks = list("abcde")
        number_of_tasks = random.randint(1, len(tasks))
        self.tasks.update(random.sample(tasks, number_of_tasks))
        print(f"Agent {self.id} initial tasks: {self.tasks}")

    def listen_for_messages(self):
        """Listen for incoming task information."""
        while self.running:
            try:
                conn, _ = self.server_socket.accept()
                with conn:
                    data = conn.recv(1024)
                    if data:
                        message = json.loads(data.decode())
                        print(f"Agent {self.id} received: {message}")
                        self.tasks.update(message["tasks"])
            except socket.timeout:
                continue
            except Exception as e:
                if self.running:
                    print(f"Agent {self.id} error: {e}")
                break

    def send_task_info(self):
        """Send task information to neighbors."""
        message = json.dumps({"id": self.id, "tasks": list(self.tasks)})
        for port in self.neighbor_ports:
            try:
                with socket.create_connection((HOST, port), timeout=1) as sock:
                    sock.sendall(message.encode())
            except (ConnectionRefusedError, socket.timeout):
                print(f"Agent {self.id} failed to connect to Agent at port {port}")

    def discover_neighbors(self):
        """Scan ports within a range to find active neighbors."""
        for port in range(BASE_PORT, BASE_PORT + PORT_RANGE):
            if port != self.port:
                try:
                    with socket.create_connection((HOST, port), timeout=0.5) as sock:
                        self.neighbor_ports.append(port)
                        print(f"Agent {self.id} detected neighbor at port {port}")
                except (ConnectionRefusedError, socket.timeout):
                    continue

    def assign_unique_task(self, assigned_tasks):
        """Choose a unique task."""
        available_tasks = self.tasks - assigned_tasks
        if available_tasks:
            self.assigned_task = available_tasks.pop()
            assigned_tasks.add(self.assigned_task)
        print(f"Agent {self.id} assigned task: {self.assigned_task}")

    def run(self):
        """Main agent behavior."""
        self.get_info()

        # Start listener thread for incoming messages
        listener_thread = threading.Thread(target=self.listen_for_messages, daemon=True)
        listener_thread.start()

        # Discover neighbors by scanning ports
        time.sleep(1)  # Allow time for agents to start their servers
        self.discover_neighbors()

        # Broadcast task information
        time.sleep(1)
        self.send_task_info()

        # Wait for task propagation
        time.sleep(2)

        # Task assignment phase
        with result_lock:
            self.assign_unique_task(assigned_tasks)

        # Close the socket and stop listening
        self.stop_listening()

    def stop_listening(self):
        """Close the server socket and stop the listening loop."""
        self.running = False
        self.server_socket.close()
        print(f"Agent {self.id}: Server socket closed.")

# %%
if __name__ == "__main__":
    assigned_tasks = set()
    result_lock = threading.Lock()
    agents = [Agent(i) for i in range(PORT_RANGE)]

    for agent in agents:
        agent.start()

    for agent in agents:
        agent.join()
# Out:
# Agent 0 initial tasks: {'a', 'd', 'e', 'c', 'b'}
# Agent 1 initial tasks: {'e', 'a', 'd'}
# Agent 2 initial tasks: {'d', 'e', 'b'}
# Agent 3 initial tasks: {'c'}
# Agent 4 initial tasks: {'a', 'd'}
# Agent 5 initial tasks: {'e', 'c', 'b'}
# Agent 6 initial tasks: {'a', 'd', 'e', 'c', 'b'}
# Agent 7 initial tasks: {'e', 'a', 'c', 'd'}
# Agent 8 initial tasks: {'e', 'a'}
# Agent 9 initial tasks: {'e', 'c', 'b', 'd'}
# Agent 4 detected neighbor at port 5000
# Agent 3 detected neighbor at port 5000
# Agent 1 detected neighbor at port 5000
# Agent 0 detected neighbor at port 5001
# Agent 6 detected neighbor at port 5000
# Agent 5 detected neighbor at port 5000
# Agent 0 detected neighbor at port 5002
# Agent 1 detected neighbor at port 5002
# Agent 7 detected neighbor at port 5000
# Agent 2 detected neighbor at port 5000
# Agent 8 detected neighbor at port 5000
# Agent 5 detected neighbor at port 5001
# Agent 9 detected neighbor at port 5000
# Agent 4 detected neighbor at port 5001
# Agent 3 detected neighbor at port 5001
# Agent 2 detected neighbor at port 5001
# Agent 1 detected neighbor at port 5003
# Agent 6 detected neighbor at port 5001
# Agent 4 detected neighbor at port 5002
# Agent 0 detected neighbor at port 5003
# Agent 7 detected neighbor at port 5001
# Agent 8 detected neighbor at port 5001
# Agent 1 detected neighbor at port 5004
# Agent 3 detected neighbor at port 5002
# Agent 9 detected neighbor at port 5001
# Agent 5 detected neighbor at port 5002
# Agent 0 detected neighbor at port 5004
# Agent 8 detected neighbor at port 5002
# Agent 6 detected neighbor at port 5002
# Agent 2 detected neighbor at port 5003
# Agent 7 detected neighbor at port 5002
# Agent 7 detected neighbor at port 5003
# Agent 3 detected neighbor at port 5004
# Agent 4 detected neighbor at port 5003
# Agent 6 detected neighbor at port 5003
# Agent 3 detected neighbor at port 5005
# Agent 5 detected neighbor at port 5003
# Agent 2 detected neighbor at port 5004
# Agent 8 detected neighbor at port 5003
# Agent 0 detected neighbor at port 5005
# Agent 1 detected neighbor at port 5005
# Agent 5 detected neighbor at port 5004
# Agent 9 detected neighbor at port 5002
# Agent 6 detected neighbor at port 5004
# Agent 7 detected neighbor at port 5004
# Agent 0 detected neighbor at port 5006
# Agent 2 detected neighbor at port 5005
# Agent 3 detected neighbor at port 5006
# Agent 6 detected neighbor at port 5005
# Agent 4 detected neighbor at port 5005
# Agent 9 detected neighbor at port 5003
# Agent 8 detected neighbor at port 5004
# Agent 7 detected neighbor at port 5005
# Agent 0 detected neighbor at port 5007
# Agent 5 detected neighbor at port 5006
# Agent 1 detected neighbor at port 5006
# Agent 6 detected neighbor at port 5007
# Agent 4 detected neighbor at port 5006
# Agent 0 detected neighbor at port 5008
# Agent 9 detected neighbor at port 5004
# Agent 3 detected neighbor at port 5007
# Agent 4 detected neighbor at port 5007
# Agent 5 detected neighbor at port 5007
# Agent 7 detected neighbor at port 5006
# Agent 6 detected neighbor at port 5008
# Agent 1 detected neighbor at port 5007
# Agent 8 detected neighbor at port 5005
# Agent 2 detected neighbor at port 5006
# Agent 3 detected neighbor at port 5008
# Agent 6 detected neighbor at port 5009
# Agent 4 detected neighbor at port 5008
# Agent 9 detected neighbor at port 5005
# Agent 7 detected neighbor at port 5008
# Agent 0 detected neighbor at port 5009
# Agent 2 detected neighbor at port 5007
# Agent 8 detected neighbor at port 5006
# Agent 1 detected neighbor at port 5008
# Agent 5 detected neighbor at port 5008
# Agent 7 detected neighbor at port 5009
# Agent 9 detected neighbor at port 5006
# Agent 3 detected neighbor at port 5009
# Agent 4 detected neighbor at port 5009
# Agent 2 detected neighbor at port 5008
# Agent 8 detected neighbor at port 5007
# Agent 2 detected neighbor at port 5009
# Agent 9 detected neighbor at port 5007
# Agent 1 detected neighbor at port 5009
# Agent 5 detected neighbor at port 5009
# Agent 9 detected neighbor at port 5008
# Agent 8 detected neighbor at port 5009
# Agent 0 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 1 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 0 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 1 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 0 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 2 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 0 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 3 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 1 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 0 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 2 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 1 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 3 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 1 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 1 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 0 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 4 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 2 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 3 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 0 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 2 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 1 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 5 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 4 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 3 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 0 received: {'id': 3, 'tasks': ['c']}
# Agent 1 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 5 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 3 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 2 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 3 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 4 received: {'id': 3, 'tasks': ['c']}
# Agent 1 received: {'id': 3, 'tasks': ['c']}
# Agent 0 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 2 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 3 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 5 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 2 received: {'id': 3, 'tasks': ['c']}
# Agent 7 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 3 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 4 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 5 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 2 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 6 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 2 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 4 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 3 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 8 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 5 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 6 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 4 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 5 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 7 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 8 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 9 received: {'id': 6, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 6 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 7 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 8 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 4 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 5 received: {'id': 3, 'tasks': ['c']}
# Agent 7 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 7 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 4 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 9 received: {'id': 7, 'tasks': ['e', 'a', 'c', 'd']}
# Agent 5 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 7 received: {'id': 3, 'tasks': ['c']}
# Agent 6 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 8 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 4 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 6 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 5 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 9 received: {'id': 4, 'tasks': ['a', 'd']}
# Agent 7 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 6 received: {'id': 3, 'tasks': ['c']}
# Agent 7 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 8 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 9 received: {'id': 1, 'tasks': ['e', 'a', 'd']}
# Agent 6 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 9 received: {'id': 0, 'tasks': ['a', 'd', 'e', 'c', 'b']}
# Agent 8 received: {'id': 9, 'tasks': ['e', 'c', 'b', 'd']}
# Agent 6 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 7 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 6 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 8 received: {'id': 3, 'tasks': ['c']}
# Agent 9 received: {'id': 3, 'tasks': ['c']}
# Agent 8 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 9 received: {'id': 5, 'tasks': ['e', 'c', 'b']}
# Agent 8 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 9 received: {'id': 8, 'tasks': ['e', 'a']}
# Agent 9 received: {'id': 2, 'tasks': ['d', 'e', 'b']}
# Agent 6 assigned task: d
# Agent 6: Server socket closed.
# Agent 7 assigned task: e
# Agent 7: Server socket closed.
# Agent 9 assigned task: a
# Agent 1 assigned task: c
# Agent 4 assigned task: b
# Agent 1: Server socket closed.
# Agent 4: Server socket closed.
# Agent 9: Server socket closed.
# Agent 0 assigned task: None
# Agent 0: Server socket closed.
# Agent 3 assigned task: None
# Agent 5 assigned task: None
# Agent 5: Server socket closed.
# Agent 3: Server socket closed.
# Agent 2 assigned task: None
# Agent 8 assigned task: None
# Agent 2: Server socket closed.
# Agent 8: Server socket closed.

# %% [markdown]
# ### Stage 6: Adding Logging because the output is getting out of hand

# %%
import socket
import threading
import json
import random
import time
import logging

HOST = "127.0.0.1"
BASE_PORT = 5000
PORT_RANGE = 10  # Adjust for the number of agents

logger = logging.getLogger()

# Console handler for CRITICAL logs only
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.CRITICAL)  # Print only CRITICAL logs to the console
console_formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console_handler.setFormatter(console_formatter)
logger.addHandler(console_handler)

# Logging setup
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("agent_logs.log"),
    ]
)

class Agent(threading.Thread):
    def __init__(self, id: int):
        super().__init__()
        self.id = id
        self.tasks = set()
        self.assigned_task = None
        self.port = BASE_PORT + id
        self.neighbor_ports = []
        self.server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.server_socket.bind((HOST, self.port))
        self.server_socket.listen()
        self.server_socket.settimeout(1)
        self.running = True

    def get_info(self):
        """Capture initial tasks."""
        tasks = list("abcde")
        number_of_tasks = random.randint(1, len(tasks))
        self.tasks.update(random.sample(tasks, number_of_tasks))
        logging.critical(f"Agent {self.id} initial tasks gathered: {self.tasks}")

    def listen_for_messages(self):
        """Listen for incoming task information."""
        while self.running:
            try:
                conn, _ = self.server_socket.accept()
                with conn:
                    data = conn.recv(1024)
                    if data:
                        message = json.loads(data.decode())
                        logging.info(f"Agent {self.id} received: {message}")
                        self.tasks.update(message["tasks"])
            except socket.timeout:
                continue
            except Exception as e:
                if self.running:
                    logging.error(f"Agent {self.id} error: {e}")
                break

    def send_task_info(self):
        """Send task information to neighbors."""
        message = json.dumps({"id": self.id, "tasks": list(self.tasks)})
        for port in self.neighbor_ports:
            try:
                with socket.create_connection((HOST, port), timeout=1) as sock:
                    sock.sendall(message.encode())
                    logging.info(f"Agent {self.id} sent tasks to Agent at port {port}")
            except (ConnectionRefusedError, socket.timeout):
                logging.warning(f"Agent {self.id} failed to connect to Agent at port {port}")

    def discover_neighbors(self):
        """Scan ports within a range to find active neighbors."""
        for port in range(BASE_PORT, BASE_PORT + PORT_RANGE):
            if port != self.port:
                try:
                    with socket.create_connection((HOST, port), timeout=0.5) as sock:
                        self.neighbor_ports.append(port)
                        logging.info(f"Agent {self.id} detected neighbor at port {port}")
                except (ConnectionRefusedError, socket.timeout):
                    continue

    def assign_unique_task(self, assigned_tasks):
        """Choose a unique task."""
        available_tasks = self.tasks - assigned_tasks
        if available_tasks:
            self.assigned_task = available_tasks.pop()
            assigned_tasks.add(self.assigned_task)
            logging.critical(f"Agent {self.id} assigned unique task: {self.assigned_task}")
        else:
            logging.warning(f"Agent {self.id} found no available unique task")

    def run(self):
        """Main agent behavior."""
        self.get_info()

        # Start listener thread for incoming messages
        listener_thread = threading.Thread(target=self.listen_for_messages, daemon=True)
        listener_thread.start()

        # Discover neighbors by scanning ports
        time.sleep(1)  # Allow time for agents to start their servers
        self.discover_neighbors()

        # Broadcast task information
        time.sleep(1)
        self.send_task_info()

        # Wait for task propagation
        time.sleep(2)

        # Task assignment phase
        with result_lock:
            self.assign_unique_task(assigned_tasks)

        # Close the socket and stop listening
        self.stop_listening()

    def stop_listening(self):
        """Close the server socket and stop the listening loop."""
        self.running = False
        self.server_socket.close()
        logging.info(f"Agent {self.id}: Server socket closed.")

# %%
# Shared resources
assigned_tasks = set()
result_lock = threading.Lock()

agents = [Agent(i) for i in range(PORT_RANGE)]

for agent in agents:
    agent.start()

for agent in agents:
    agent.join()
# Out:
# 2025-01-28 20:02:12,142 - CRITICAL - Agent 0 initial tasks gathered: {'a', 'd', 'c', 'e'}
# 2025-01-28 20:02:12,142 - CRITICAL - Agent 0 initial tasks gathered: {'a', 'd', 'c', 'e'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 1 initial tasks gathered: {'c'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 2 initial tasks gathered: {'a', 'd', 'c'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 1 initial tasks gathered: {'c'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 3 initial tasks gathered: {'a', 'd'}
# 2025-01-28 20:02:12,145 - CRITICAL - Agent 4 initial tasks gathered: {'d'}
# 2025-01-28 20:02:12,160 - CRITICAL - Agent 5 initial tasks gathered: {'c', 'd', 'e'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 2 initial tasks gathered: {'a', 'd', 'c'}
# 2025-01-28 20:02:12,161 - CRITICAL - Agent 6 initial tasks gathered: {'a', 'd', 'e'}
# 2025-01-28 20:02:12,144 - CRITICAL - Agent 3 initial tasks gathered: {'a', 'd'}
# 2025-01-28 20:02:12,163 - CRITICAL - Agent 7 initial tasks gathered: {'a', 'e'}
# 2025-01-28 20:02:12,164 - CRITICAL - Agent 8 initial tasks gathered: {'d'}
# 2025-01-28 20:02:12,165 - CRITICAL - Agent 9 initial tasks gathered: {'b', 'c'}
# 2025-01-28 20:02:12,145 - CRITICAL - Agent 4 initial tasks gathered: {'d'}
# 2025-01-28 20:02:12,160 - CRITICAL - Agent 5 initial tasks gathered: {'c', 'd', 'e'}
# 2025-01-28 20:02:12,161 - CRITICAL - Agent 6 initial tasks gathered: {'a', 'd', 'e'}
# 2025-01-28 20:02:12,163 - CRITICAL - Agent 7 initial tasks gathered: {'a', 'e'}
# 2025-01-28 20:02:12,164 - CRITICAL - Agent 8 initial tasks gathered: {'d'}
# 2025-01-28 20:02:12,165 - CRITICAL - Agent 9 initial tasks gathered: {'b', 'c'}
# 2025-01-28 20:02:13,165 - INFO - Agent 0 detected neighbor at port 5001
# 2025-01-28 20:02:13,166 - INFO - Agent 0 detected neighbor at port 5002
# 2025-01-28 20:02:13,167 - INFO - Agent 0 detected neighbor at port 5003
# 2025-01-28 20:02:13,169 - INFO - Agent 1 detected neighbor at port 5000
# 2025-01-28 20:02:13,171 - INFO - Agent 2 detected neighbor at port 5000
# 2025-01-28 20:02:13,171 - INFO - Agent 2 detected neighbor at port 5001
# 2025-01-28 20:02:13,172 - INFO - Agent 2 detected neighbor at port 5003
# 2025-01-28 20:02:13,173 - INFO - Agent 2 detected neighbor at port 5004
# 2025-01-28 20:02:13,175 - INFO - Agent 5 detected neighbor at port 5000
# 2025-01-28 20:02:13,175 - INFO - Agent 4 detected neighbor at port 5000
# 2025-01-28 20:02:13,176 - INFO - Agent 6 detected neighbor at port 5000
# 2025-01-28 20:02:13,176 - INFO - Agent 5 detected neighbor at port 5001
# 2025-01-28 20:02:13,176 - INFO - Agent 4 detected neighbor at port 5001
# 2025-01-28 20:02:13,177 - INFO - Agent 7 detected neighbor at port 5000
# 2025-01-28 20:02:13,177 - INFO - Agent 8 detected neighbor at port 5000
# 2025-01-28 20:02:13,178 - INFO - Agent 6 detected neighbor at port 5001
# 2025-01-28 20:02:13,178 - INFO - Agent 4 detected neighbor at port 5002
# 2025-01-28 20:02:13,178 - INFO - Agent 5 detected neighbor at port 5002
# 2025-01-28 20:02:13,178 - INFO - Agent 9 detected neighbor at port 5000
# 2025-01-28 20:02:13,179 - INFO - Agent 7 detected neighbor at port 5001
# 2025-01-28 20:02:13,180 - INFO - Agent 8 detected neighbor at port 5001
# 2025-01-28 20:02:13,180 - INFO - Agent 6 detected neighbor at port 5002
# 2025-01-28 20:02:13,182 - INFO - Agent 5 detected neighbor at port 5003
# 2025-01-28 20:02:13,182 - INFO - Agent 9 detected neighbor at port 5001
# 2025-01-28 20:02:13,183 - INFO - Agent 7 detected neighbor at port 5002
# 2025-01-28 20:02:13,183 - INFO - Agent 8 detected neighbor at port 5002
# 2025-01-28 20:02:13,184 - INFO - Agent 6 detected neighbor at port 5003
# 2025-01-28 20:02:13,185 - INFO - Agent 5 detected neighbor at port 5004
# 2025-01-28 20:02:13,185 - INFO - Agent 9 detected neighbor at port 5002
# 2025-01-28 20:02:13,186 - INFO - Agent 7 detected neighbor at port 5003
# 2025-01-28 20:02:13,187 - INFO - Agent 8 detected neighbor at port 5003
# 2025-01-28 20:02:13,187 - INFO - Agent 3 detected neighbor at port 5000
# 2025-01-28 20:02:13,187 - INFO - Agent 0 detected neighbor at port 5004
# 2025-01-28 20:02:13,187 - INFO - Agent 1 detected neighbor at port 5002
# 2025-01-28 20:02:13,187 - INFO - Agent 2 detected neighbor at port 5005
# 2025-01-28 20:02:13,188 - INFO - Agent 6 detected neighbor at port 5004
# 2025-01-28 20:02:13,188 - INFO - Agent 5 detected neighbor at port 5006
# 2025-01-28 20:02:13,189 - INFO - Agent 9 detected neighbor at port 5003
# 2025-01-28 20:02:13,189 - INFO - Agent 7 detected neighbor at port 5004
# 2025-01-28 20:02:13,190 - INFO - Agent 8 detected neighbor at port 5004
# 2025-01-28 20:02:13,191 - INFO - Agent 3 detected neighbor at port 5001
# 2025-01-28 20:02:13,192 - INFO - Agent 0 detected neighbor at port 5005
# 2025-01-28 20:02:13,192 - INFO - Agent 1 detected neighbor at port 5003
# 2025-01-28 20:02:13,193 - INFO - Agent 2 detected neighbor at port 5006
# 2025-01-28 20:02:13,193 - INFO - Agent 6 detected neighbor at port 5005
# 2025-01-28 20:02:13,194 - INFO - Agent 5 detected neighbor at port 5007
# 2025-01-28 20:02:13,194 - INFO - Agent 9 detected neighbor at port 5004
# 2025-01-28 20:02:13,195 - INFO - Agent 7 detected neighbor at port 5005
# 2025-01-28 20:02:13,196 - INFO - Agent 8 detected neighbor at port 5005
# 2025-01-28 20:02:13,196 - INFO - Agent 3 detected neighbor at port 5002
# 2025-01-28 20:02:13,197 - INFO - Agent 0 detected neighbor at port 5006
# 2025-01-28 20:02:13,197 - INFO - Agent 1 detected neighbor at port 5004
# 2025-01-28 20:02:13,198 - INFO - Agent 2 detected neighbor at port 5007
# 2025-01-28 20:02:13,199 - INFO - Agent 6 detected neighbor at port 5007
# 2025-01-28 20:02:13,199 - INFO - Agent 5 detected neighbor at port 5008
# 2025-01-28 20:02:13,200 - INFO - Agent 9 detected neighbor at port 5005
# 2025-01-28 20:02:13,200 - INFO - Agent 7 detected neighbor at port 5006
# 2025-01-28 20:02:13,202 - INFO - Agent 8 detected neighbor at port 5006
# 2025-01-28 20:02:13,202 - INFO - Agent 3 detected neighbor at port 5004
# 2025-01-28 20:02:13,202 - INFO - Agent 0 detected neighbor at port 5007
# 2025-01-28 20:02:13,202 - INFO - Agent 1 detected neighbor at port 5005
# 2025-01-28 20:02:13,203 - INFO - Agent 4 detected neighbor at port 5003
# 2025-01-28 20:02:13,203 - INFO - Agent 2 detected neighbor at port 5008
# 2025-01-28 20:02:13,204 - INFO - Agent 6 detected neighbor at port 5008
# 2025-01-28 20:02:13,204 - INFO - Agent 5 detected neighbor at port 5009
# 2025-01-28 20:02:13,205 - INFO - Agent 9 detected neighbor at port 5006
# 2025-01-28 20:02:13,206 - INFO - Agent 7 detected neighbor at port 5008
# 2025-01-28 20:02:13,206 - INFO - Agent 8 detected neighbor at port 5007
# 2025-01-28 20:02:13,207 - INFO - Agent 3 detected neighbor at port 5005
# 2025-01-28 20:02:13,208 - INFO - Agent 0 detected neighbor at port 5008
# 2025-01-28 20:02:13,208 - INFO - Agent 1 detected neighbor at port 5006
# 2025-01-28 20:02:13,208 - INFO - Agent 4 detected neighbor at port 5005
# 2025-01-28 20:02:13,209 - INFO - Agent 2 detected neighbor at port 5009
# 2025-01-28 20:02:13,209 - INFO - Agent 6 detected neighbor at port 5009
# 2025-01-28 20:02:13,211 - INFO - Agent 9 detected neighbor at port 5007
# 2025-01-28 20:02:13,211 - INFO - Agent 7 detected neighbor at port 5009
# 2025-01-28 20:02:13,212 - INFO - Agent 8 detected neighbor at port 5009
# 2025-01-28 20:02:13,213 - INFO - Agent 1 detected neighbor at port 5007
# 2025-01-28 20:02:13,213 - INFO - Agent 0 detected neighbor at port 5009
# 2025-01-28 20:02:13,213 - INFO - Agent 3 detected neighbor at port 5006
# 2025-01-28 20:02:13,214 - INFO - Agent 4 detected neighbor at port 5006
# 2025-01-28 20:02:13,215 - INFO - Agent 9 detected neighbor at port 5008
# 2025-01-28 20:02:13,218 - INFO - Agent 1 detected neighbor at port 5008
# 2025-01-28 20:02:13,218 - INFO - Agent 3 detected neighbor at port 5007
# 2025-01-28 20:02:13,219 - INFO - Agent 4 detected neighbor at port 5007
# 2025-01-28 20:02:13,220 - INFO - Agent 1 detected neighbor at port 5009
# 2025-01-28 20:02:13,221 - INFO - Agent 3 detected neighbor at port 5008
# 2025-01-28 20:02:13,221 - INFO - Agent 4 detected neighbor at port 5008
# 2025-01-28 20:02:13,222 - INFO - Agent 3 detected neighbor at port 5009
# 2025-01-28 20:02:13,223 - INFO - Agent 4 detected neighbor at port 5009
# 2025-01-28 20:02:14,210 - INFO - Agent 5 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,210 - INFO - Agent 0 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,232 - INFO - Agent 0 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,232 - INFO - Agent 2 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,232 - INFO - Agent 1 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,232 - INFO - Agent 5 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,232 - INFO - Agent 3 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 4 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 7 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 1 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 8 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 9 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 6 sent tasks to Agent at port 5000
# 2025-01-28 20:02:14,233 - INFO - Agent 0 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,247 - INFO - Agent 2 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,248 - INFO - Agent 0 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,248 - INFO - Agent 2 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,248 - INFO - Agent 1 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,250 - INFO - Agent 5 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,250 - INFO - Agent 3 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,251 - INFO - Agent 4 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,251 - INFO - Agent 7 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,252 - INFO - Agent 1 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,257 - INFO - Agent 8 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,257 - INFO - Agent 0 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,257 - INFO - Agent 9 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,258 - INFO - Agent 6 sent tasks to Agent at port 5001
# 2025-01-28 20:02:14,258 - INFO - Agent 2 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,267 - INFO - Agent 2 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,260 - INFO - Agent 3 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,260 - INFO - Agent 2 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,260 - INFO - Agent 1 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,261 - INFO - Agent 5 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,262 - INFO - Agent 3 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,263 - INFO - Agent 4 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,264 - INFO - Agent 7 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,264 - INFO - Agent 1 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,265 - INFO - Agent 8 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,265 - INFO - Agent 0 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,266 - INFO - Agent 9 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,259 - INFO - Agent 0 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,267 - INFO - Agent 6 sent tasks to Agent at port 5002
# 2025-01-28 20:02:14,269 - INFO - Agent 2 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,270 - INFO - Agent 3 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,271 - INFO - Agent 2 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,271 - INFO - Agent 4 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,271 - INFO - Agent 1 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,272 - INFO - Agent 5 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,273 - INFO - Agent 4 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,273 - INFO - Agent 3 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,274 - INFO - Agent 7 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,275 - INFO - Agent 1 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,276 - INFO - Agent 0 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,276 - INFO - Agent 8 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,277 - INFO - Agent 9 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,278 - INFO - Agent 0 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,279 - INFO - Agent 6 sent tasks to Agent at port 5003
# 2025-01-28 20:02:14,280 - INFO - Agent 2 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,280 - INFO - Agent 3 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,295 - INFO - Agent 5 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,295 - INFO - Agent 2 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,295 - INFO - Agent 4 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,296 - INFO - Agent 1 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,298 - INFO - Agent 4 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,298 - INFO - Agent 5 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,299 - INFO - Agent 3 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,299 - INFO - Agent 6 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,299 - INFO - Agent 7 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,301 - INFO - Agent 1 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,301 - INFO - Agent 0 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,302 - INFO - Agent 8 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,303 - INFO - Agent 9 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,303 - INFO - Agent 0 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,304 - INFO - Agent 2 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,304 - INFO - Agent 6 sent tasks to Agent at port 5004
# 2025-01-28 20:02:14,306 - INFO - Agent 3 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,307 - INFO - Agent 5 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,308 - INFO - Agent 2 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,308 - INFO - Agent 4 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,309 - INFO - Agent 1 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,311 - INFO - Agent 5 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,311 - INFO - Agent 4 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,312 - INFO - Agent 7 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,312 - INFO - Agent 3 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,312 - INFO - Agent 6 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,313 - INFO - Agent 7 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,313 - INFO - Agent 0 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,314 - INFO - Agent 1 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,314 - INFO - Agent 8 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,315 - INFO - Agent 9 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,316 - INFO - Agent 2 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,316 - INFO - Agent 0 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,317 - INFO - Agent 6 sent tasks to Agent at port 5005
# 2025-01-28 20:02:14,317 - INFO - Agent 3 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,317 - INFO - Agent 5 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,318 - INFO - Agent 4 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,318 - INFO - Agent 2 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,319 - INFO - Agent 1 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,322 - INFO - Agent 4 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,322 - INFO - Agent 5 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,322 - INFO - Agent 8 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,322 - INFO - Agent 7 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,323 - INFO - Agent 3 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,323 - INFO - Agent 6 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,324 - INFO - Agent 0 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,325 - INFO - Agent 7 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,325 - INFO - Agent 1 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,326 - INFO - Agent 8 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,326 - INFO - Agent 9 sent tasks to Agent at port 5006
# 2025-01-28 20:02:14,327 - INFO - Agent 2 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,327 - INFO - Agent 0 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,328 - INFO - Agent 6 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,328 - INFO - Agent 3 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,329 - INFO - Agent 5 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,330 - INFO - Agent 4 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,330 - INFO - Agent 2 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,331 - INFO - Agent 1 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,332 - INFO - Agent 4 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,334 - INFO - Agent 8 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,334 - INFO - Agent 5 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,334 - INFO - Agent 9 received: {'id': 5, 'tasks': ['c', 'd', 'e']}
# 2025-01-28 20:02:14,335 - INFO - Agent 7 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,336 - INFO - Agent 3 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,336 - INFO - Agent 6 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,336 - INFO - Agent 0 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,337 - INFO - Agent 7 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,338 - INFO - Agent 1 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,339 - INFO - Agent 8 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,339 - INFO - Agent 9 sent tasks to Agent at port 5007
# 2025-01-28 20:02:14,340 - INFO - Agent 2 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,340 - INFO - Agent 0 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,341 - INFO - Agent 6 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,342 - INFO - Agent 3 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,342 - INFO - Agent 5 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,343 - INFO - Agent 4 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,343 - INFO - Agent 2 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,343 - INFO - Agent 1 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,344 - INFO - Agent 4 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,344 - INFO - Agent 8 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,347 - INFO - Agent 9 received: {'id': 2, 'tasks': ['a', 'd', 'c']}
# 2025-01-28 20:02:14,348 - INFO - Agent 7 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,348 - INFO - Agent 6 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,349 - INFO - Agent 3 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,350 - INFO - Agent 7 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,350 - INFO - Agent 1 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,351 - INFO - Agent 8 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,351 - INFO - Agent 9 sent tasks to Agent at port 5008
# 2025-01-28 20:02:14,352 - INFO - Agent 0 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,354 - INFO - Agent 3 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,354 - INFO - Agent 6 sent tasks to Agent at port 5009
# 2025-01-28 20:02:14,354 - INFO - Agent 5 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,355 - INFO - Agent 4 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,357 - INFO - Agent 8 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,357 - INFO - Agent 9 received: {'id': 4, 'tasks': ['d']}
# 2025-01-28 20:02:14,358 - INFO - Agent 7 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,358 - INFO - Agent 6 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,362 - INFO - Agent 3 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,363 - INFO - Agent 5 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,364 - INFO - Agent 4 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,364 - INFO - Agent 8 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,365 - INFO - Agent 9 received: {'id': 3, 'tasks': ['a', 'd']}
# 2025-01-28 20:02:14,365 - INFO - Agent 7 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,366 - INFO - Agent 6 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,367 - INFO - Agent 5 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,368 - INFO - Agent 4 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,369 - INFO - Agent 8 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,369 - INFO - Agent 9 received: {'id': 7, 'tasks': ['a', 'e']}
# 2025-01-28 20:02:14,370 - INFO - Agent 7 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,371 - INFO - Agent 6 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,371 - INFO - Agent 5 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,373 - INFO - Agent 8 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,374 - INFO - Agent 9 received: {'id': 1, 'tasks': ['c']}
# 2025-01-28 20:02:14,374 - INFO - Agent 7 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,375 - INFO - Agent 6 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,376 - INFO - Agent 8 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:14,377 - INFO - Agent 9 received: {'id': 8, 'tasks': ['d']}
# 2025-01-28 20:02:14,377 - INFO - Agent 7 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,378 - INFO - Agent 8 received: {'id': 9, 'tasks': ['b', 'c']}
# 2025-01-28 20:02:14,379 - INFO - Agent 9 received: {'id': 0, 'tasks': ['a', 'd', 'c', 'e']}
# 2025-01-28 20:02:14,381 - INFO - Agent 9 received: {'id': 6, 'tasks': ['a', 'd', 'e']}
# 2025-01-28 20:02:16,347 - CRITICAL - Agent 5 assigned unique task: b
# 2025-01-28 20:02:16,347 - CRITICAL - Agent 5 assigned unique task: b
# 2025-01-28 20:02:16,348 - INFO - Agent 5: Server socket closed.
# 2025-01-28 20:02:16,356 - CRITICAL - Agent 2 assigned unique task: a
# 2025-01-28 20:02:16,356 - CRITICAL - Agent 2 assigned unique task: a
# 2025-01-28 20:02:16,357 - CRITICAL - Agent 4 assigned unique task: d
# 2025-01-28 20:02:16,357 - CRITICAL - Agent 4 assigned unique task: d
# 2025-01-28 20:02:16,357 - INFO - Agent 2: Server socket closed.
# 2025-01-28 20:02:16,358 - INFO - Agent 4: Server socket closed.
# 2025-01-28 20:02:16,360 - CRITICAL - Agent 3 assigned unique task: c
# 2025-01-28 20:02:16,360 - CRITICAL - Agent 3 assigned unique task: c
# 2025-01-28 20:02:16,361 - CRITICAL - Agent 7 assigned unique task: e
# 2025-01-28 20:02:16,361 - CRITICAL - Agent 7 assigned unique task: e
# 2025-01-28 20:02:16,361 - INFO - Agent 3: Server socket closed.
# 2025-01-28 20:02:16,362 - WARNING - Agent 1 found no available unique task
# 2025-01-28 20:02:16,362 - INFO - Agent 7: Server socket closed.
# 2025-01-28 20:02:16,362 - INFO - Agent 1: Server socket closed.
# 2025-01-28 20:02:16,362 - WARNING - Agent 8 found no available unique task
# 2025-01-28 20:02:16,364 - WARNING - Agent 9 found no available unique task
# 2025-01-28 20:02:16,364 - INFO - Agent 8: Server socket closed.
# 2025-01-28 20:02:16,364 - WARNING - Agent 0 found no available unique task
# 2025-01-28 20:02:16,365 - INFO - Agent 9: Server socket closed.
# 2025-01-28 20:02:16,366 - INFO - Agent 0: Server socket closed.
# 2025-01-28 20:02:16,366 - WARNING - Agent 6 found no available unique task
# 2025-01-28 20:02:16,367 - INFO - Agent 6: Server socket closed.

# %% [markdown]
# ### Stage 7: Dockerized Agents

# %% [markdown]
# Making Dockerfile and Docker-Compose and stuff of stage 6 in the work dir
# 1. Create a network using:
# ```bash
# docker network create agent_network
# ```
# 2. Create Volume for Logs:
# ```bash
# docker volume create agent_logs
# ```
# 3. ```bash
# docker-compose up --build
# ```

# %% [markdown]
# ### Stage 8: One Agent per Container

# %%
import threading
import socket
import json
import random
import time
import logging
import os

# Get the environment variables for the container's ID and other settings
HOST = os.getenv("HOST", "0.0.0.0")
BASE_PORT = int(os.getenv("BASE_PORT", 5000))
PORT_RANGE = int(os.getenv("PORT_RANGE", 10))  # Number of agents to run
AGENT_ID = int(os.getenv("AGENT_ID", 0))  # Get agent ID from environment variable

# Logging setup to write to a shared volume
log_file = "/logs/agent_logs.log"
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.FileHandler(log_file), logging.StreamHandler()],
)


class Agent:
    def __init__(self, id: int):
        self.id = id
        self.tasks = set()
        self.assigned_task = None
        self.port = BASE_PORT + id
        self.neighbor_ports = []
        self.server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.server_socket.bind((HOST, self.port))
        self.server_socket.listen()
        self.server_socket.settimeout(1)
        self.running = True

    def get_info(self):
        """Capture initial tasks."""
        tasks = list("abcde")
        number_of_tasks = random.randint(1, len(tasks))
        self.tasks.update(random.sample(tasks, number_of_tasks))
        logging.critical(f"Agent {self.id} initial tasks gathered: {self.tasks}")

    def listen_for_messages(self):
        """Listen for incoming task information."""
        while self.running:
            try:
                conn, _ = self.server_socket.accept()
                with conn:
                    data = conn.recv(1024)
                    if data:
                        message = json.loads(data.decode())
                        logging.info(f"Agent {self.id} received: {message}")
                        self.tasks.update(message["tasks"])
            except socket.timeout:
                continue
            except Exception as e:
                if self.running:
                    logging.error(f"Agent {self.id} error: {e}")
                break

    def send_task_info(self):
        """Send task information to neighbors."""
        message = json.dumps({"id": self.id, "tasks": list(self.tasks)})
        for port in self.neighbor_ports:
            try:
                with socket.create_connection((HOST, port), timeout=1) as sock:
                    sock.sendall(message.encode())
                    logging.info(f"Agent {self.id} sent tasks to Agent at port {port}")
            except (ConnectionRefusedError, socket.timeout):
                logging.warning(
                    f"Agent {self.id} failed to connect to Agent at port {port}"
                )

    def discover_neighbors(self):
        """Scan ports within a range to find active neighbors."""
        for port in range(BASE_PORT, BASE_PORT + PORT_RANGE):
            if port != self.port:
                try:
                    with socket.create_connection((HOST, port), timeout=0.5) as sock:
                        self.neighbor_ports.append(port)
                        logging.info(
                            f"Agent {self.id} detected neighbor at port {port}"
                        )
                except (ConnectionRefusedError, socket.timeout):
                    continue

    def assign_unique_task(self, assigned_tasks):
        """Choose a unique task."""
        available_tasks = self.tasks - assigned_tasks
        if available_tasks:
            self.assigned_task = available_tasks.pop()
            assigned_tasks.add(self.assigned_task)
            logging.critical(
                f"Agent {self.id} assigned unique task: {self.assigned_task}"
            )
        else:
            logging.warning(f"Agent {self.id} found no available unique task")

    def run(self):
        """Main agent behavior."""
        self.get_info()

        # Start listener thread for incoming messages
        listener_thread = threading.Thread(target=self.listen_for_messages, daemon=True)
        listener_thread.start()

        # Discover neighbors by scanning ports
        time.sleep(1)  # Allow time for agents to start their servers
        self.discover_neighbors()

        # Network discovery phase: wait for 10 seconds
        time.sleep(10)
        logging.critical(f"Agent {self.id} completed network discovery.")

        # Broadcast task information
        self.send_task_info()

        # Wait for task propagation
        time.sleep(2)

        # Task assignment phase
        with result_lock:
            self.assign_unique_task(assigned_tasks)

        # Output gathered information and assigned task
        logging.critical(
            f"Agent {self.id} info gathered: {self.tasks}, assigned task: {self.assigned_task}"
        )

        # Close the socket and stop listening
        self.stop_listening()

    def stop_listening(self):
        """Close the server socket and stop the listening loop."""
        self.running = False
        self.server_socket.close()
        logging.info(f"Agent {self.id}: Server socket closed.")


# Shared resources
assigned_tasks = set()
result_lock = threading.Lock()

if __name__ == "__main__":
    agent = Agent(id=AGENT_ID)  # Use the agent ID from environment
    agent.run()

# %% [markdown]
# ### Stage 9: Task uniqueness using some auction-like algorithm
